# %%
import pandas as pd
import matplotlib.pyplot as plt
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
df=pd.read_csv("instagram_data.csv")
df
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#        owner_id     owner_username    shortcode  is_video  \
# 0      36063641  christendominique  C3_GS1ASeWI     False
# 1      36063641  christendominique  C38ivgNS3IX      True
# 2      36063641  christendominique  C35-Dd9SO1b      True
# 3      36063641  christendominique  C33TadDMisq      True
# 4      36063641  christendominique  C3s-Cm1yCba      True
# ..          ...                ...          ...       ...
# 994  1552043361         el_kilombo  C3_GSnJuc_n     False
# 995  1552043361         el_kilombo  C3-3lf7upwU     False
# 996  1552043361         el_kilombo  C3-2X4PuDNg     False
# 997  1552043361         el_kilombo  C3-vi6BuXue      True
# 998    12148448       emilyschuman  C4BPuM9xuNU      True
#
#                                                caption  comments  likes  \
# 0    I’m a brunch & Iced Coffee girlie☕️🍳 \n\nTop @...       268  16382
# 1    😮‍💨Brow tips I really wish I would have know w...       138   9267
# 2    OMG I can’t believe it’s already been 1 yr sin...      1089  10100
# 3    90’s Glam was Pam! \n\nMakeup \n@smashboxcosme...       271   6943
# 4    Chiseled & Sculptured 🏛️\n\n Contour @westmana...       145  17158
# ..                                                 ...       ...    ...
# 994  Snoop Dogg se aventuró en la programación infa...        71   7519
# 995                                           Perdón 😬        32  21427
# 996  El director James Gunn anuncia que ha comenzad...        37   5234
# 997                        🐼🎋\n\n🎥: @chinapandafanlily        89  27490
# 998  In my long nail era (and how I apply press-ons...        32   1515
#
#      created_at location                                           imageUrl  \
# 0    1709326758      NaN  https://instagram.flba2-1.fna.fbcdn.net/v/t39....
# 1    1709241048      NaN  https://instagram.flba2-1.fna.fbcdn.net/v/t51....
# 2    1709154707      NaN  https://instagram.flba2-1.fna.fbcdn.net/v/t51....
# 3    1709065322      NaN  https://instagram.flba2-1.fna.fbcdn.net/v/t51....
# 4    1708718486      NaN  https://instagram.flba2-1.fna.fbcdn.net/v/t51....
# ..          ...      ...                                                ...
# 994  1709326756      NaN  https://instagram.fkiv3-1.fna.fbcdn.net/v/t39....
# 995  1709319047      NaN  https://instagram.fkiv3-1.fna.fbcdn.net/v/t39....
# 996  1709318411      NaN  https://instagram.fkiv3-1.fna.fbcdn.net/v/t39....
# 997  1709314921      NaN  https://instagram.fkiv3-1.fna.fbcdn.net/v/t51....
# 998  1709398859      NaN  https://instagram.fkiv2-1.fna.fbcdn.net/v/t51....
#
#      multiple_images           username  followers  following
# 0               True  christendominique  2144626.0     1021.0
# 1              False  christendominique  2144626.0     1021.0
# 2              False  christendominique  2144626.0     1021.0
# 3              False  christendominique  2144626.0     1021.0
# 4              False  christendominique  2144626.0     1021.0
# ..               ...                ...        ...        ...
# 994            False         el_kilombo  4841844.0     1015.0
# 995            False         el_kilombo  4841844.0     1015.0
# 996             True         el_kilombo  4841844.0     1015.0
# 997            False         el_kilombo  4841844.0     1015.0
# 998            False       emilyschuman   602683.0     1298.0
#
# [999 rows x 14 columns]

# %%
df.head()
# Out:
#    owner_id     owner_username    shortcode  is_video  \
# 0  36063641  christendominique  C3_GS1ASeWI     False
# 1  36063641  christendominique  C38ivgNS3IX      True
# 2  36063641  christendominique  C35-Dd9SO1b      True
# 3  36063641  christendominique  C33TadDMisq      True
# 4  36063641  christendominique  C3s-Cm1yCba      True
#
#                                              caption  comments  likes  \
# 0  I’m a brunch & Iced Coffee girlie☕️🍳 \n\nTop @...       268  16382
# 1  😮‍💨Brow tips I really wish I would have know w...       138   9267
# 2  OMG I can’t believe it’s already been 1 yr sin...      1089  10100
# 3  90’s Glam was Pam! \n\nMakeup \n@smashboxcosme...       271   6943
# 4  Chiseled & Sculptured 🏛️\n\n Contour @westmana...       145  17158
#
#    created_at location                                           imageUrl  \
# 0  1709326758      NaN  https://instagram.flba2-1.fna.fbcdn.net/v/t39....
# 1  1709241048      NaN  https://instagram.flba2-1.fna.fbcdn.net/v/t51....
# 2  1709154707      NaN  https://instagram.flba2-1.fna.fbcdn.net/v/t51....
# 3  1709065322      NaN  https://instagram.flba2-1.fna.fbcdn.net/v/t51....
# 4  1708718486      NaN  https://instagram.flba2-1.fna.fbcdn.net/v/t51....
#
#    multiple_images           username  followers  following
# 0             True  christendominique  2144626.0     1021.0
# 1            False  christendominique  2144626.0     1021.0
# 2            False  christendominique  2144626.0     1021.0
# 3            False  christendominique  2144626.0     1021.0
# 4            False  christendominique  2144626.0     1021.0

# %%
df.tail()
# Out:
#        owner_id owner_username    shortcode  is_video  \
# 994  1552043361     el_kilombo  C3_GSnJuc_n     False
# 995  1552043361     el_kilombo  C3-3lf7upwU     False
# 996  1552043361     el_kilombo  C3-2X4PuDNg     False
# 997  1552043361     el_kilombo  C3-vi6BuXue      True
# 998    12148448   emilyschuman  C4BPuM9xuNU      True
#
#                                                caption  comments  likes  \
# 994  Snoop Dogg se aventuró en la programación infa...        71   7519
# 995                                           Perdón 😬        32  21427
# 996  El director James Gunn anuncia que ha comenzad...        37   5234
# 997                        🐼🎋\n\n🎥: @chinapandafanlily        89  27490
# 998  In my long nail era (and how I apply press-ons...        32   1515
#
#      created_at location                                           imageUrl  \
# 994  1709326756      NaN  https://instagram.fkiv3-1.fna.fbcdn.net/v/t39....
# 995  1709319047      NaN  https://instagram.fkiv3-1.fna.fbcdn.net/v/t39....
# 996  1709318411      NaN  https://instagram.fkiv3-1.fna.fbcdn.net/v/t39....
# 997  1709314921      NaN  https://instagram.fkiv3-1.fna.fbcdn.net/v/t51....
# 998  1709398859      NaN  https://instagram.fkiv2-1.fna.fbcdn.net/v/t51....
#
#      multiple_images      username  followers  following
# 994            False    el_kilombo  4841844.0     1015.0
# 995            False    el_kilombo  4841844.0     1015.0
# 996             True    el_kilombo  4841844.0     1015.0
# 997            False    el_kilombo  4841844.0     1015.0
# 998            False  emilyschuman   602683.0     1298.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   owner_id         999 non-null    int64
#  1   owner_username   999 non-null    object
#  2   shortcode        999 non-null    object
#  3   is_video         999 non-null    bool
#  4   caption          991 non-null    object
#  5   comments         999 non-null    int64
#  6   likes            999 non-null    int64
#  7   created_at       999 non-null    int64
#  8   location         360 non-null    object
#  9   imageUrl         999 non-null    object
#  10  multiple_images  999 non-null    bool
#  11  username         883 non-null    object
#  12  followers        883 non-null    float64
#  13  following        883 non-null    float64
# dtypes: bool(2), float64(2), int64(4), object(6)
# memory usage: 95.7+ KB

# %%
df.isnull().sum()
# Out:
# owner_id             0
# owner_username       0
# shortcode            0
# is_video             0
# caption              8
# comments             0
# likes                0
# created_at           0
# location           639
# imageUrl             0
# multiple_images      0
# username           116
# followers          116
# following          116
# dtype: int64

# %% [markdown]
# **Preprocess captions removing special characters and converting to lowecase**

# %%
df['caption'] = df['caption'].str.replace('[^\w\s]', '')  # Remove special chars
df['caption'] = df['caption'].str.lower()         # Convert to lowercase

# %% [markdown]
# **Filling missing values**

# %%
df['location'] = df['location'].fillna('Unknown')  # Non-numeric column
df['username'] = df['username'].fillna('NoUsername')  # Non-numeric column
df['followers'] = df['followers'].fillna(df['followers'].mean())  # Numeric column
df['following'] = df['following'].fillna(df['following'].mean())  # Numeric column
df['caption'] = df['caption'].astype(str)

# %% [markdown]
# **Check the missing values in colums**

# %%
print(df.isnull().sum())
# Out:
# owner_id           0
# owner_username     0
# shortcode          0
# is_video           0
# caption            0
# comments           0
# likes              0
# created_at         0
# location           0
# imageUrl           0
# multiple_images    0
# username           0
# followers          0
# following          0
# dtype: int64

# %% [markdown]
# **Sentiment Analysis**

# %%
sid = SentimentIntensityAnalyzer()
df['sentiment_score'] = df['caption'].apply(lambda x: sid.polarity_scores(x)['compound'])

# %% [markdown]
# **Classify sentiment**

# %%
df['sentiment'] = pd.cut(df['sentiment_score'], bins=[-1, -0.01, 0.01, 1], labels=['Negative', 'Neutral', 'Positive'])

# %% [markdown]
# **Visualize sentiment trends over time**

# %%
df['created_at'] = pd.to_datetime(df['created_at'], unit='s')
df['date'] = df['created_at'].dt.date
sentiment_trends = df.groupby('date')['sentiment_score'].mean()
plt.plot(sentiment_trends)
plt.title('Sentiment Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Average Sentiment Score')
plt.show()

# %% [markdown]
# **Sentiment Distribution**

# %%
df['sentiment'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Sentiment Distribution')
plt.show()

# %%
plt.hist(df['sentiment_score'], bins=20, color='skyblue', edgecolor='black')
plt.title('Sentiment Score Distribution')
plt.xlabel('Sentiment Score')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import seaborn as sns

sns.boxplot(x='sentiment', y='sentiment_score', data=df, hue='sentiment', palette='Set2', legend=False)
plt.title('Sentiment Score by Sentiment Category')
plt.xlabel('Sentiment')
plt.ylabel('Sentiment Score')
plt.show()

# %%
from wordcloud import WordCloud

for sentiment in ['Positive', 'Neutral', 'Negative']:
    text = ' '.join(df[df['sentiment'] == sentiment]['caption'])
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f'Word Cloud for {sentiment} Captions')
    plt.axis('off')
    plt.show()

# %%
df['sentiment'].value_counts().plot(kind='bar', color=['green', 'blue', 'red'], figsize=(8, 6))
plt.title('Count of Posts by Sentiment')
plt.xlabel('Sentiment')
plt.ylabel('Number of Posts')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
numerical_cols = ['likes', 'comments', 'followers', 'following', 'sentiment_score']
correlation_matrix = df[numerical_cols].corr()

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Between Features')
plt.show()

# %%
sns.boxplot(x='sentiment', y='likes', data=df, hue='sentiment', palette='muted', legend=False)
plt.title('Likes Distribution by Sentiment')
plt.xlabel('Sentiment')
plt.ylabel('Likes')
plt.show()

sns.boxplot(x='sentiment', y='comments', data=df, hue='sentiment', palette='muted', legend=False)
plt.title('Comments Distribution by Sentiment')
plt.xlabel('Sentiment')
plt.ylabel('Comments')
plt.show()
